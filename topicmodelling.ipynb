# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import ast

# Load the CSV file
df = pd.read_csv('cleaned_comments.csv')

# Get the first 10 unique video IDs
unique_video_ids = df['Video ID'].unique()[:10]

# Loop through each video ID and generate a word cloud
for video_id in unique_video_ids:
    # Filter rows by video ID
    filtered_df = df[df['Video ID'] == video_id]

    # Extract tokens and combine into a single list
    all_tokens = []
    for tokens_str in filtered_df['Tokens']:
        tokens_list = ast.literal_eval(tokens_str)
        all_tokens.extend(tokens_list)

    # Join all tokens into a single string
    text = ' '.join(all_tokens)

    # Generate the word cloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud
    plt.figure(figsize=(10, 5))
    plt.title(f'Word Cloud for Video ID: {video_id}')
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
import pandas as pd
from gensim import corpora, models

print(pd.__version__)

# Load the data from the CSV file into a DataFrame
comments_df = pd.read_csv('cleaned_comments.csv')
descriptions_df = pd.read_csv('descriptions.csv')

merged_df = pd.merge(comments_df, descriptions_df, on='Video ID', suffixes=('_comments', '_descriptions'))

personality_keywords = ['personality', 'friend', 'friendly', 'funny', 'house', 'home', 'love', 'beautiful']

video_ids = merged_df['Video ID'].unique()

topics_data = []

for video_id in video_ids:
    filtered_comments = merged_df[(merged_df['Video ID'] == video_id) & ~merged_df['Tokens'].str.contains('|'.join(personality_keywords))]['Tokens'].apply(eval).tolist()
    filtered_descriptions = merged_df[merged_df['Video ID'] == video_id]['Main Description'].tolist()
    
    # Convert descriptions to list of lists
    filtered_descriptions = [[description] for description in filtered_descriptions]

    # Combine comments and descriptions
    combined_text = [comment + description for comment, description in zip(filtered_comments, filtered_descriptions)]

    # Create Dictionary
    dictionary = corpora.Dictionary(combined_text)

    # Create Corpus: Term Document Frequency
    corpus = [dictionary.doc2bow(text) for text in combined_text]

    # Train LDA Model
    num_topics = 10  # Number of topics you want to discover
    lda_model = models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=10)
    # Save topics to the DataFrame
    for topic in lda_model.print_topics():
        topics_data.append({'Video ID': video_id, 'Topic': topic})
        
    # Print topics for the first video
    print(f"Topics for Video ID: {video_id}")
    for topic in lda_model.print_topics():
        print(topic)
        
# Convert the list of topics to a DataFrame
topics_df = pd.DataFrame(topics_data)

# Save the DataFrame to a CSV file
topics_df.to_csv('topics.csv', index=False)
# Out:
# 2.2.2
# Topics for Video ID: kavjzsRtuuA
# (0, '0.141*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.016*"dude" + 0.014*"cool" + 0.012*"enjoyed" + 0.010*"guy" + 0.010*"something" + 0.010*"hate" + 0.007*"one" + 0.007*"know" + 0.007*"could"')
# (1, '0.053*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.010*"girl" + 0.010*"casa" + 0.005*"sea" + 0.005*"type" + 0.005*"far" + 0.005*"watched" + 0.005*"lucky" + 0.005*"smile" + 0.005*"time"')
# (2, '0.037*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.018*"one" + 0.015*"hollywood" + 0.010*"people" + 0.010*"taste" + 0.005*"art" + 0.005*"knows" + 0.005*"table" + 0.005*"place" + 0.005*"maybe"')
# (3, '0.146*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.015*"know" + 0.013*"vibe" + 0.011*"shower" + 0.010*"video" + 0.010*"que" + 0.010*"want" + 0.010*"gomez" + 0.008*"still" + 0.006*"dude"')
# (4, '0.111*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.023*"get" + 0.020*"cute" + 0.018*"know" + 0.013*"girl" + 0.011*"like" + 0.008*"think" + 0.008*"want" + 0.007*"one" + 0.007*"super"')
# (5, '0.110*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.030*"cold" + 0.025*"plunge" + 0.015*"help" + 0.015*"faster" + 0.015*"emails" + 0.015*"going" + 0.013*"getting" + 0.013*"hilarious" + 0.012*"write"')
# (6, '0.142*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.050*"guy" + 0.032*"like" + 0.025*"seems" + 0.021*"nice" + 0.012*"fun" + 0.010*"see" + 0.010*"people" + 0.008*"room" + 0.007*"person"')
# (7, '0.158*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.016*"seems" + 0.013*"awesome" + 0.009*"fun" + 0.009*"amazing" + 0.007*"like" + 0.007*"got" + 0.007*"earth" + 0.007*"much" + 0.007*"together"')
# (8, '0.162*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.048*"like" + 0.016*"best" + 0.014*"looks" + 0.013*"dude" + 0.013*"seems" + 0.011*"guy" + 0.010*"get" + 0.009*"cool" + 0.009*"blurred"')
# (9, '0.136*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.038*"lol" + 0.029*"guy" + 0.017*"see" + 0.014*"seems" + 0.012*"energy" + 0.011*"cool" + 0.011*"like" + 0.010*"totally" + 0.008*"get"')
# Topics for Video ID: XxPPdlo72ho
# (0, '0.099*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.021*"like" + 0.012*"untari" + 0.012*"lestari" + 0.011*"everything" + 0.010*"style" + 0.010*"ttembok" + 0.009*"queen" + 0.007*"chic" + 0.007*"something"')
# (1, '0.112*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.027*"cozy" + 0.023*"like" + 0.017*"room" + 0.015*"nice" + 0.014*"warm" + 0.014*"would" + 0.010*"feels" + 0.010*"sons" + 0.010*"chanel"')
# (2, '0.048*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.021*"bathroom" + 0.016*"doll" + 0.016*"though" + 0.011*"amazing" + 0.011*"want" + 0.011*"every" + 0.011*"anyone" + 0.011*"monster" + 0.007*"know"')
# (3, '0.138*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.032*"like" + 0.018*"ship" + 0.016*"chandelier" + 0.010*"ever" + 0.008*"one" + 0.008*"end" + 0.008*"charming" + 0.008*"girl" + 0.008*"pouring"')
# (4, '0.140*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.012*"pool" + 0.010*"wow" + 0.009*"got" + 0.009*"chandelier" + 0.009*"like" + 0.007*"doll" + 0.006*"nice" + 0.006*"cool" + 0.006*"looks"')
# (5, '0.201*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.020*"dolls" + 0.015*"one" + 0.014*"best" + 0.013*"cute" + 0.011*"favorite" + 0.009*"son" + 0.009*"doll" + 0.009*"like" + 0.009*"amazing"')
# (6, '0.128*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.032*"cord" + 0.032*"covers" + 0.017*"doll" + 0.017*"obsessed" + 0.015*"wall" + 0.015*"need" + 0.013*"fire" + 0.011*"yes" + 0.010*"like"')
# (7, '0.081*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.024*"casa" + 0.018*"que" + 0.015*"could" + 0.011*"first" + 0.011*"barbie" + 0.007*"character" + 0.007*"appreciate" + 0.007*"human" + 0.007*"def"')
# (8, '0.090*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.027*"never" + 0.020*"would" + 0.017*"cool" + 0.017*"hate" + 0.011*"look" + 0.010*"make" + 0.009*"think" + 0.009*"video" + 0.009*"ever"')
# (9, '0.121*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.019*"like" + 0.016*"please" + 0.013*"think" + 0.013*"rich" + 0.013*"still" + 0.010*"vibe" + 0.010*"high" + 0.007*"girl" + 0.007*"dolls"')
# Topics for Video ID: VylU-ueLA_g
# (0, '0.137*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.044*"papa" + 0.012*"got" + 0.011*"made" + 0.009*"minimalist" + 0.009*"kitchen" + 0.009*"minimal" + 0.009*"waiting" + 0.009*"like" + 0.009*"must"')
# (1, '0.150*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.053*"minimalist" + 0.017*"like" + 0.017*"cool" + 0.015*"texas" + 0.012*"lol" + 0.010*"would" + 0.010*"dude" + 0.009*"looks" + 0.009*"mansion"')
# (2, '0.091*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.017*"sonic" + 0.014*"got" + 0.014*"ice" + 0.012*"cooking" + 0.012*"would" + 0.012*"kitchen" + 0.012*"get" + 0.011*"papa" + 0.010*"lol"')
# (3, '0.060*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.026*"uncle" + 0.022*"roger" + 0.013*"taste" + 0.009*"money" + 0.009*"wait" + 0.009*"ultimate" + 0.009*"ugly" + 0.009*"airbnb" + 0.008*"ahh"')
# (4, '0.125*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.032*"know" + 0.031*"would" + 0.016*"lol" + 0.016*"minimalist" + 0.015*"rich" + 0.014*"yes" + 0.013*"like" + 0.012*"thought" + 0.011*"guy"')
# (5, '0.109*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.035*"guy" + 0.015*"like" + 0.012*"come" + 0.009*"happy" + 0.009*"videos" + 0.009*"pretentious" + 0.009*"never" + 0.006*"nice" + 0.006*"room"')
# (6, '0.137*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.010*"would" + 0.009*"super" + 0.009*"thought" + 0.009*"bro" + 0.007*"papa" + 0.007*"like" + 0.007*"big" + 0.007*"look" + 0.007*"keep"')
# (7, '0.120*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.013*"kitchen" + 0.012*"got" + 0.010*"think" + 0.008*"vase" + 0.008*"lambo" + 0.008*"papa" + 0.008*"vibes" + 0.008*"gives" + 0.008*"space"')
# ...
# (3, '0.163*"[\'ad\', \'welcomed\', \'tour\', \'peaceful\', \'sustainable\', \'home\', \'los\', \'alongside\', \'illustrious\', \'modeling\', \'supermodel\', \'also\', \'keen\', \'climate\', \'change\', \'came\', \'designing\', \'sustainability\', \'enlisted\', \'friend\', \'interior\', \'designer\', \'ross\', \'cassidy\', \'help\', \'design\', \'stylish\', \'yet\', \'paint\', \'walls\', \'replaced\', \'natural\', \'clay\', \'exterior\', \'clad\', \'light\', \'stone\', \'last\', \'upholstered\', \'furniture\', \'sustainable\', \'materials\', \'went\', \'vintage\', \'artisanal\', \'fill\', \'decor\', \'full\', \'earthy\', \'tones\', \'organic\', \'peaceful\', \'sustainable\', \'sanctuary\', \'looking\', \'place\', \'come\', \'see\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'photographs\', \'richard\', \'richard\', \'avedon\', \'foundation\', \'ellsworth\', \'kelly\', \'blue\', \'green\', \'red\', \'portfolio\', \'artists\', \'edition\', \'x\', \'inches\', \'ellsworth\', \'kelly\', \'foundation\', \'gemini\', \'llc\', \'glen\', \'luchford\', \'art\', \'partner\', \'trunk\', \'archive\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.043*"vintage" + 0.016*"white" + 0.014*"one" + 0.014*"bla" + 0.011*"gorgeous" + 0.008*"dog" + 0.008*"climate" + 0.008*"rich" + 0.008*"french"')
# (4, '0.063*"[\'ad\', \'welcomed\', \'tour\', \'peaceful\', \'sustainable\', \'home\', \'los\', \'alongside\', \'illustrious\', \'modeling\', \'supermodel\', \'also\', \'keen\', \'climate\', \'change\', \'came\', \'designing\', \'sustainability\', \'enlisted\', \'friend\', \'interior\', \'designer\', \'ross\', \'cassidy\', \'help\', \'design\', \'stylish\', \'yet\', \'paint\', \'walls\', \'replaced\', \'natural\', \'clay\', \'exterior\', \'clad\', \'light\', \'stone\', \'last\', \'upholstered\', \'furniture\', \'sustainable\', \'materials\', \'went\', \'vintage\', \'artisanal\', \'fill\', \'decor\', \'full\', \'earthy\', \'tones\', \'organic\', \'peaceful\', \'sustainable\', \'sanctuary\', \'looking\', \'place\', \'come\', \'see\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'photographs\', \'richard\', \'richard\', \'avedon\', \'foundation\', \'ellsworth\', \'kelly\', \'blue\', \'green\', \'red\', \'portfolio\', \'artists\', \'edition\', \'x\', \'inches\', \'ellsworth\', \'kelly\', \'foundation\', \'gemini\', \'llc\', \'glen\', \'luchford\', \'art\', \'partner\', \'trunk\', \'archive\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.031*"beige" + 0.014*"amazing" + 0.011*"male" + 0.011*"hairdresser" + 0.011*"like" + 0.011*"calm" + 0.011*"many" + 0.011*"bold" + 0.011*"kitchen"')
# (5, '0.052*"[\'ad\', \'welcomed\', \'tour\', \'peaceful\', \'sustainable\', \'home\', \'los\', \'alongside\', \'illustrious\', \'modeling\', \'supermodel\', \'also\', \'keen\', \'climate\', \'change\', \'came\', \'designing\', \'sustainability\', \'enlisted\', \'friend\', \'interior\', \'designer\', \'ross\', \'cassidy\', \'help\', \'design\', \'stylish\', \'yet\', \'paint\', \'walls\', \'replaced\', \'natural\', \'clay\', \'exterior\', \'clad\', \'light\', \'stone\', \'last\', \'upholstered\', \'furniture\', \'sustainable\', \'materials\', \'went\', \'vintage\', \'artisanal\', \'fill\', \'decor\', \'full\', \'earthy\', \'tones\', \'organic\', \'peaceful\', \'sustainable\', \'sanctuary\', \'looking\', \'place\', \'come\', \'see\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'photographs\', \'richard\', \'richard\', \'avedon\', \'foundation\', \'ellsworth\', \'kelly\', \'blue\', \'green\', \'red\', \'portfolio\', \'artists\', \'edition\', \'x\', \'inches\', \'ellsworth\', \'kelly\', \'foundation\', \'gemini\', \'llc\', \'glen\', \'luchford\', \'art\', \'partner\', \'trunk\', \'archive\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.021*"bedroom" + 0.021*"see" + 0.021*"fun" + 0.011*"accent" + 0.011*"could" + 0.011*"need" + 0.011*"fit" + 0.011*"clean" + 0.011*"white"')
# (6, '0.065*"[\'ad\', \'welcomed\', \'tour\', \'peaceful\', \'sustainable\', \'home\', \'los\', \'alongside\', \'illustrious\', \'modeling\', \'supermodel\', \'also\', \'keen\', \'climate\', \'change\', \'came\', \'designing\', \'sustainability\', \'enlisted\', \'friend\', \'interior\', \'designer\', \'ross\', \'cassidy\', \'help\', \'design\', \'stylish\', \'yet\', \'paint\', \'walls\', \'replaced\', \'natural\', \'clay\', \'exterior\', \'clad\', \'light\', \'stone\', \'last\', \'upholstered\', \'furniture\', \'sustainable\', \'materials\', \'went\', \'vintage\', \'artisanal\', \'fill\', \'decor\', \'full\', \'earthy\', \'tones\', \'organic\', \'peaceful\', \'sustainable\', \'sanctuary\', \'looking\', \'place\', \'come\', \'see\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'photographs\', \'richard\', \'richard\', \'avedon\', \'foundation\', \'ellsworth\', \'kelly\', \'blue\', \'green\', \'red\', \'portfolio\', \'artists\', \'edition\', \'x\', \'inches\', \'ellsworth\', \'kelly\', \'foundation\', \'gemini\', \'llc\', \'glen\', \'luchford\', \'art\', \'partner\', \'trunk\', \'archive\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.012*"vintage" + 0.012*"gorgeous" + 0.012*"nice" + 0.012*"light" + 0.012*"supermodels" + 0.012*"enjoyed" + 0.012*"never" + 0.012*"looks" + 0.012*"frenchman"')
# (7, '0.079*"[\'ad\', \'welcomed\', \'tour\', \'peaceful\', \'sustainable\', \'home\', \'los\', \'alongside\', \'illustrious\', \'modeling\', \'supermodel\', \'also\', \'keen\', \'climate\', \'change\', \'came\', \'designing\', \'sustainability\', \'enlisted\', \'friend\', \'interior\', \'designer\', \'ross\', \'cassidy\', \'help\', \'design\', \'stylish\', \'yet\', \'paint\', \'walls\', \'replaced\', \'natural\', \'clay\', \'exterior\', \'clad\', \'light\', \'stone\', \'last\', \'upholstered\', \'furniture\', \'sustainable\', \'materials\', \'went\', \'vintage\', \'artisanal\', \'fill\', \'decor\', \'full\', \'earthy\', \'tones\', \'organic\', \'peaceful\', \'sustainable\', \'sanctuary\', \'looking\', \'place\', \'come\', \'see\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'photographs\', \'richard\', \'richard\', \'avedon\', \'foundation\', \'ellsworth\', \'kelly\', \'blue\', \'green\', \'red\', \'portfolio\', \'artists\', \'edition\', \'x\', \'inches\', \'ellsworth\', \'kelly\', \'foundation\', \'gemini\', \'llc\', \'glen\', \'luchford\', \'art\', \'partner\', \'trunk\', \'archive\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.038*"california" + 0.029*"boring" + 0.020*"favourite" + 0.020*"cities" + 0.020*"allegra" + 0.020*"cole" + 0.010*"look" + 0.010*"french" + 0.010*"even"')
# (8, '0.114*"[\'ad\', \'welcomed\', \'tour\', \'peaceful\', \'sustainable\', \'home\', \'los\', \'alongside\', \'illustrious\', \'modeling\', \'supermodel\', \'also\', \'keen\', \'climate\', \'change\', \'came\', \'designing\', \'sustainability\', \'enlisted\', \'friend\', \'interior\', \'designer\', \'ross\', \'cassidy\', \'help\', \'design\', \'stylish\', \'yet\', \'paint\', \'walls\', \'replaced\', \'natural\', \'clay\', \'exterior\', \'clad\', \'light\', \'stone\', \'last\', \'upholstered\', \'furniture\', \'sustainable\', \'materials\', \'went\', \'vintage\', \'artisanal\', \'fill\', \'decor\', \'full\', \'earthy\', \'tones\', \'organic\', \'peaceful\', \'sustainable\', \'sanctuary\', \'looking\', \'place\', \'come\', \'see\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'photographs\', \'richard\', \'richard\', \'avedon\', \'foundation\', \'ellsworth\', \'kelly\', \'blue\', \'green\', \'red\', \'portfolio\', \'artists\', \'edition\', \'x\', \'inches\', \'ellsworth\', \'kelly\', \'foundation\', \'gemini\', \'llc\', \'glen\', \'luchford\', \'art\', \'partner\', \'trunk\', \'archive\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.037*"stunning" + 0.028*"furniture" + 0.019*"curation" + 0.019*"said" + 0.019*"elegant" + 0.010*"need" + 0.010*"wow" + 0.010*"nice" + 0.010*"french"')
# (9, '0.156*"[\'ad\', \'welcomed\', \'tour\', \'peaceful\', \'sustainable\', \'home\', \'los\', \'alongside\', \'illustrious\', \'modeling\', \'supermodel\', \'also\', \'keen\', \'climate\', \'change\', \'came\', \'designing\', \'sustainability\', \'enlisted\', \'friend\', \'interior\', \'designer\', \'ross\', \'cassidy\', \'help\', \'design\', \'stylish\', \'yet\', \'paint\', \'walls\', \'replaced\', \'natural\', \'clay\', \'exterior\', \'clad\', \'light\', \'stone\', \'last\', \'upholstered\', \'furniture\', \'sustainable\', \'materials\', \'went\', \'vintage\', \'artisanal\', \'fill\', \'decor\', \'full\', \'earthy\', \'tones\', \'organic\', \'peaceful\', \'sustainable\', \'sanctuary\', \'looking\', \'place\', \'come\', \'see\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'photographs\', \'richard\', \'richard\', \'avedon\', \'foundation\', \'ellsworth\', \'kelly\', \'blue\', \'green\', \'red\', \'portfolio\', \'artists\', \'edition\', \'x\', \'inches\', \'ellsworth\', \'kelly\', \'foundation\', \'gemini\', \'llc\', \'glen\', \'luchford\', \'art\', \'partner\', \'trunk\', \'archive\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.021*"dog" + 0.021*"thought" + 0.018*"nice" + 0.012*"like" + 0.011*"see" + 0.011*"fiance" + 0.011*"poor" + 0.011*"lydia" + 0.011*"faking"')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[88], line 19
#      16 topics_data = []
#      18 for video_id in video_ids:
# ---> 19     filtered_comments = merged_df[(merged_df['Video ID'] == video_id) & ~merged_df['Tokens'].str.contains('|'.join(personality_keywords))]['Tokens'].apply(eval).tolist()
#      20     filtered_descriptions = merged_df[merged_df['Video ID'] == video_id]['Main Description'].tolist()
#      22     # Convert descriptions to list of lists
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/pandas/core/strings/accessor.py:137, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     132     msg = (
#     133         f"Cannot use .str.{func_name} with values of "
#     134         f"inferred dtype '{self._inferred_dtype}'."
#     135     )
#     136     raise TypeError(msg)
# --> 137 return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/pandas/core/strings/accessor.py:1335, in StringMethods.contains(self, pat, case, flags, na, regex)
#    1327 if regex and re.compile(pat).groups:
#    1328     warnings.warn(
#    1329         "This pattern is interpreted as a regular expression, and has "
#    1330         "match groups. To actually get the groups, use str.extract.",
#    1331         UserWarning,
#    1332         stacklevel=find_stack_level(),
#    1333     )
# -> 1335 result = self._data.array._str_contains(pat, case, flags, na, regex)
#    1336 return self._wrap_result(result, fill_value=na, returns_string=False)
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/pandas/core/strings/object_array.py:145, in ObjectStringArrayMixin._str_contains(self, pat, case, flags, na, regex)
#     143         upper_pat = pat.upper()
#     144         f = lambda x: upper_pat in x.upper()
# --> 145 return self._str_map(f, na, dtype=np.dtype("bool"))
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/pandas/core/strings/object_array.py:78, in ObjectStringArrayMixin._str_map(self, f, na_value, dtype, convert)
#      76 map_convert = convert and not np.all(mask)
#      77 try:
# ---> 78     result = lib.map_infer_mask(arr, f, mask.view(np.uint8), map_convert)
#      79 except (TypeError, AttributeError) as err:
#      80     # Reraise the exception if callable `f` got wrong number of args.
#      81     # The user may want to be warned by this, instead of getting NaN
#      82     p_err = (
#      83         r"((takes)|(missing)) (?(2)from \d+ to )?\d+ "
#      84         r"(?(3)required )positional arguments?"
#      85     )
#
# File lib.pyx:2895, in pandas._libs.lib.map_infer_mask()
#
# File lib.pyx:2932, in pandas._libs.lib._map_infer_mask()
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/pandas/core/strings/object_array.py:138, in ObjectStringArrayMixin._str_contains.<locals>.<lambda>(x)
#     134         flags |= re.IGNORECASE
#     136     pat = re.compile(pat, flags=flags)
# --> 138     f = lambda x: pat.search(x) is not None
#     139 else:
#     140     if case:
#
# KeyboardInterrupt:

# %%
import pandas as pd
import ast

# Read the topics.csv file into a DataFrame
topics_df = pd.read_csv('topics.csv')

# Convert the 'Topic' column to string type
topics_df['Topic'] = topics_df['Topic'].astype(str)

# Function to clean and parse the topic strings
def clean_and_parse_topic(topic_str):
    try:
        # Remove leading and trailing parentheses and any tuple formatting
        topic_str = topic_str.strip("()")
        parts = topic_str.split(", ", 1)
        if len(parts) > 1:
            topic_str = parts[1]
        
        # Replace specific problematic characters
        cleaned_str = topic_str.replace('""', '').replace("'", "").replace('\\', '')
        
        # Extract the description weight
        desc_weight = float(cleaned_str.split("*")[0])
        
        # Extract the topics
        topics = []
        parts = cleaned_str.split(" + ")
        for part in parts:
            if '*' in part:
                _, topic = part.split('*', 1)
                topic = topic.strip()
                topics.append(topic)
        return desc_weight, topics
    except Exception as e:
        print(f"Error processing '{topic_str}': {e}")
        return None, None


# Group by 'Video ID'
grouped = topics_df.groupby('Video ID')

# Function to extract top 5 topics based on weights
def get_top_5_topics(group):
    topics = []
    for _, row in group.iterrows():
        desc_weight, topic_info = clean_and_parse_topic(row['Topic'])
        if topic_info:
            topics.append((desc_weight, topic_info))
    # Sort topics based on description weights and select the top 5
    top_5_topics = sorted(topics, key=lambda x: x[0], reverse=True)[:5]
    return [(weight, topic) for weight, topic in top_5_topics]


# Apply the function to each group and concatenate the results
result = grouped.apply(get_top_5_topics).reset_index()
result.columns = ['Video ID', 'Top 5 Topics']

# Write the result to a new CSV file
result.to_csv('top_5_topics.csv', index=False)
# Out:
# /var/folders/qv/dfs9xlmx52x51qbbcp3zlfj00000gn/T/ipykernel_90151/496021732.py:55: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result = grouped.apply(get_top_5_topics).reset_index()

# %%
import csv
import ast  # For safe evaluation of string representations of lists

# Open the input and output files
with open('top_5_topics.csv', 'r', newline='', encoding='utf-8') as input_file, \
     open('cleaned_top_5_topics.csv', 'w', newline='', encoding='utf-8') as output_file:
    reader = csv.reader(input_file)
    writer = csv.writer(output_file)

    writer.writerow(['Video ID', 'Weight', 'Topics'])

    next(reader)

    # Iterate over each row in the input file
    for row in reader:
        video_id = row[0]  # Extract video ID
        topics = eval(row[1])  # Convert the string representation of topics to a list

        # Iterate over each topic in the list
        for weight, topic_list in topics:
            topic_list = [topic for topic in topic_list if not topic.startswith('[') and not topic.endswith(']')]
            topic_string = ', '.join(topic_list)  # Convert the topic list to a string
            writer.writerow([video_id, weight, topic_string])

print("Cleaning complete. Output saved to cleaned_top_5_topics.csv")
# Out:
# Cleaning complete. Output saved to cleaned_top_5_topics.csv

# %%
import pandas as pd
import ast

# Read the CSV file
df = pd.read_csv("cleaned_top_5_topics.csv")

# Function to process the Topics column
def process_topics(topics): 
    # Remove the triple quotes and split the string into two parts
    parts = topics.replace('"""', '').split('", "', 1)
    
    # Check if there are two parts
    if len(parts) == 2:
        # Add a closing quote to the second part if it's missing
        if not parts[1].endswith('"'):
            parts[1] += '"'
        # Parse the second part as a list and return it as a string
        try:
            return str(ast.literal_eval(parts[1]))
        except SyntaxError:
            return parts[1]
    else:
        # If there's only one part, return it as is
        return parts[0]


# Apply the function to the Topics column
df['Topics'] = df['Topics'].apply(process_topics)


df.to_csv("cleaned_top_5_topics.csv", index=False)

# %%
from collections import defaultdict, Counter

df = pd.read_csv("cleaned_top_5_topics.csv")

topics_dict = defaultdict(set)
word_counter = Counter()

remove_words = ["love", "loved", "lovely", "house", "home", "like", "gorgeous", "amazing", "beautiful", "ever", 
                "lol", "omg", "nice", "like", "cool", "best", "looks", "would", "one", "much", "room",
                "look", "wow", "see", "good", "know", "stunning", "people", "want", "style", "seen", "place", 
                "video", "taste", "cute", "everything", "well", "absolutely", "get", "space", "anyone", "tour",
                "apartment", "money", "design", "vibe", "could", "seems", "way", "favorite", "happy", "rich", "thank",
                "two", "still", "need", "every", "feel", "show", "many", "got", "damn", "time", "please", "thought", "blurred",
                "homes", "voice", "someone", "yes", "actually", "done", "god", "life", "going", "ariel", "pretty", "laugh", "person",
                "together", "though", "always", "thing", "vibes", "also", "day", "else", "episode", "say", "que", "think", "melo", "little",
                "loves", "awesome", "never", "rooms", "proud", "riverdale", "job", "queen", "watch", "sharing", "thanks", "lady", "married", 
                "right", "baby", "houses"]

# Process the data
for index, row in df.iterrows():
    video_id, weight, topics = row['Video ID'], row['Weight'], row['Topics']
    # Remove extra quotation marks
    topics = topics.replace('"', '')
    topics = topics.split(", ")
    word_counter.update(topics)
    topics = [topic for topic in topics if topic not in remove_words]
    topics_dict[video_id].update(topics)
    
sd_topics = pd.DataFrame(columns=['Video ID', 'Topics'])

# Print the results
for video_id, topics in topics_dict.items():
    print(f"{video_id}: {', '.join(topics)}")
    new_row = pd.DataFrame({'Video ID': [video_id], 'Topics': [', '.join(topics)]})
    sd_topics = pd.concat([sd_topics, new_row], ignore_index=True)
        
sd_topics.to_csv('sd_topics.csv', index=False)

print("\nMost common words:")
for word, count in word_counter.most_common(10):  
    print(f"{word}: {count}")
# Out:
# -TeeIEh2IE8: gallery, second, elmo, remember, trophies, keep, art, chair, nepal, cold, body, museum, magazine, times, trash, trophy, door, unique
# -zkOLKMiX9c: woman, art, pepper, old, body, white
# 0K9eZCW-lvc: tate, kitchen, body, sweet, something, dress, cozy
# 0_BEwbnmRZ4: sounds, leave, panic, humor, jazzy, guy, hilarious, man, monotone, spanish
# 5WH-PSs9hI8: mama, fracking, drag, black, disco, color, closet, joy, white
# 5vNoHwgoIjw: coop, chickens, fish, mcguire, samsung, chicken, girl, sons, lizzie, kids, dress
# 5zvsAwsEwPg: couple, story, sweet, joy, wife
# 7R2RyqU4hjI: title, accent, garden, couple, catherine, pot, mcnulty, haunted, castle, wonderful, ancestors, family, needs, irish
# 7Z76MiQv0zg: sword, woman, lotr, soul, soothing, magnolia, attic, display, arwen, sweet, tree, asmr
# 7cGmj0AR3z8: creepy, statue, colombian, jersey, guy, bedroom, coffee, quality, casa, colombia, handsome, neymar, hot
# 80z6drP0NY8: player, miss, mind, hard, furniture, guy, future, come, man, decor, vacation, nba, kids, first, court, older, basketball, jordan
# 8MkcEzfyCFM: player, collection, respect, art, guy, piece, crib, dope, salute, brother
# 9KapEXWynrA: painting, forever, large, buy, wondering, three, frame, art, wrong, wall, elena, kitchen, far, deal, yummy, texture, things, feels
# 9OvibwfflDg: cook, perfection, accent, woman, latin, learn, birds, una, closet, crystal, exquisite
# 9p9sGtV4UoU: cat, celebrities, oleander, art, upstate, toilet, bathroom, outfit, kids, dead, etsy, cozy
# ATGZ58IRwfE: poppy, gay, couple, ricky, traffic, play, kitchen, girl, sad, tree, family, needs, new, daughter
# AkTkUOOCZ-w: ice, everybody, couple, bunk, shoes, age, family, bed, cozy, wife
# AwhBTrzzqeg: green, limes, soothing, movie, red, bedroom, coolest, book, kitchen, girl, neighbors, table, bamboo, dog, shades
# Axg27gwEqCE: garden, sonata, remember, obsessed, gary, bathroom, girl, far, celebrity, mozart, beethoven
# BDA6rPA0Fcs: gay, couple, nph, art, barney, suit, flip, book, kitchen, scooter, bar
# D-qQneOnJl0: cook, couple, todd, pinkman, open, white, cooking, bad, cabin, lab, stone, finally, minerals, cozy, warm, meth
# D_gkHpZ2oRI: honest, authentic, definitely, garden, furniture, books, fun, boring
# EB_Z-8kBNm8: piano, amy, comic, pond, obsessed, kitchen, charming, yorkshire, fun, blue, door, scottish, cozy
# EobMnSpjfTU: part, gay, world, melbourne, sense, couch, sweet, shirt, imagine, made, super, cozy
# ExTP2rYqguE: mike, claire, couple, ross, let, perfect, rachel, tell, bathroom, feels, favourite
# FIDsKWis3jo: view, smog, particular, built, wood, girl, dress, big, cozy
# GiYK_6FxNts: modern, definitely, couple, inside, leonard, black, cold, interior, hotel, personal, edmonton, dog, cozy, boring, white
# HphRKCxIK_Q: watching, picture, woman, shot, husband, line, brazilian, wearing, zip, says, jumpsuit, kids, family, naked, pics, daughter, spanish
# IxlzRwNX63A: collection, woman, artwork, dressing, art, classy, elegance, elegant, closet
# JKUWL85Betk: sheeps, whole, model, meh, gold, pictures, bad, black, color, plural, sorry, girl, sheep, interior, con, decor, boring, white
# Jzqu48uup54: merry, takes, dude, rug, oval, white, aside, president, clinton, office, coke, america, guy, politics, word, believe, christmas, monica, eyes, youtube
# KHfP3InQc94: kourtneys, kourtney, guy, black, years, calm, candle, dude, kourt, family, kardashian, food, vegan, cozy
# KIqQ0gowzt4: rains, happens, whole, woman, cribs, kenyan, furniture, villa, africa, hotel, believe, african, age, malindi, kenya, resort, luxury
# KuYsILv6Fd0: poppy, couple, safe, children, kitchen, kids, family, new
# KyI8i1-cN8s: wallpaper, respect, light, cave, yogurt, dude, humble, computer, office, energy, let, guy, clean, bed, super, around, jayztwocents, man, saw, sell, away, dad, kids, things, made, even, wife
# Li8ubUzLB90: modern, cam, chicken, adu, yard, sure, finally, victoria, family, first, mitchell
# LpVraZRIjrY: leather, dogs, wallpaper, gucci, cloud, art, farmhouse, kitchen, fun, sure, unique
# NXrwxbxeqCE: dogs, beach, marble, small, stove, kitchen, bathroom, dog, cozy
# P-7mzzWtnVQ: christmas, paris, bowl, fluffing, mom, tree, trees, fluffer
# PKAM4M9OET8: garden, beata, eclectic, shower, art, bedroom, stuff, unique
# PWnDS45iDj4: cars, modern, pants, similar, inviting, old, guy, sweatpants, rings, table, wearing, man, brand, cozy, warm, big
# PqpCeiYycVM: congrats, literally, art, books, obsessed, dad, insane, girl, new
# Pt_5Faa_J-U: მოვტყან, ზარბო, russia, kind, hubby, შარაპოვა, maple, warm, cold, walls, შენი, дом, inviting, concrete, sara, sorry, tree, ვთხარე, მინეტი, spot, tennis, art
# QMCR45FyfzU: back, lannister, energy, leo, guy, fern, simple, tshirt, hand, มวยไทย, fookin, pants, jaime, man, jamie, shirt, course, muay, brienne, doll, lion, thai
# Qc0iJpQcdis: pots, wallpaper, hanna, dining, ceiling, kitchen, hotel, idea, laundry, marin, even
# QvoPw_5Sz8U: fender, wallpaper, channel, couple, spice, fireplace, perfect, attention, kitchen, club, mouse, utah, make
# RDn0K9UzCpc: view, skirt, bronx, girl, decor, outfit, dog, pope
# RF-Mqs2qC-M: dude, door, poor, kind, skittles, hotel, alia, mansion, million, pot, came, small, perfect, hell, man, tree, machine, ali, idea, made
# RNjlfo_8u4s: office, couple, mose, shrute, lord, dwight, guy, tell, farm, farms, schrute, fun, beet, use, beets, mindy, warm
# RjVfU9WcPxE: ago, energy, chef, art, bloscar, guy, broke, back, man, food, roman
# S1_L6RGDggk: tall, beach, sweater, boys, art, guy, man, american, dude, cardigan, dog, wife
# SVO-iq2bjTQ: moment, spot, definitely, lamp, small, chair, light, pictures, table, sunshine, decor, girl, sweet, elm, surrounded, bed, first, sofa
# SrlAlMsdr3g: might, creepy, couple, clean, winchester, toilet, doll, bathroom, supernatural, tree, kids, wife
# TPEdTajhR6A: hat, earth, couple, sam, air, supernatural, waiting, conditioning, thinking, gen, family, dark, cozy, different, humble
# UAUfo6KY1wg: buy, universe, couple, mediterranean, trust, outdoor, color, clothes, fashion, blue, white
# UYEWJcmWKGQ: simply, couple, husband, talk, black, power, hang, warm, favourite
# VTPdktgrtF8: ronald, office, mural, limes, work, incredible, studio, come, zhc, far
# VabOWgtG2D4: couple, enjoy, art, children, kitchen, kids, family
# VxvfhuxOE1I: around, barn, chapel, creepy, ebay, property, church, horses, interesting
# VyEf4EBXe8o: tesla, led, fish, juul, mango, old, baseball, shoes, picture, million, bowl, sucker, child, tie, lmao, pod, dad, kids, snoop, grandma, views, year, wait
# VylU-ueLA_g: minimalist, uncle, roger, art, bro, guy, come, kitchen, soulless, nothing, austin, youtube, papa
# X89WJTXA8KQ: energy, bedroom, color, sweet, colors, full
# XNrTIQjHuKs: sounds, couple, gomez, jessie, lip, ohio, cyrus, hey, bite, hair, coolest, bust, miley, columbus, dwayne, corn
# XxPPdlo72ho: dolls, collector, collection, creepy, chandelier, wall, doll, bathroom, celebrity, cozy, ship, hate
# YQC7OtyHhxU: gay, vision, husband, heart, mug, close, candle, man, human, sweet, note, closet, lot, blah, basement
# _Jqi9k3tXoQ: piano, expensive, song, dimmer, world, york, keep, bangs, city, bidet, bathroom, name, plants, new, loft
# _Zr3ObadDnI: uncle, letter, billy, couple, trump, scott, man, family, full, big, wife
# aB7JCNRI3rY: wallpaper, glass, cabinets, wall, paper, kitchen, windows, idea, makes, beautifully
# aTSgJgRnqG0: idol, gay, goddess, knew, durga, cam, expecting, mitch, idea, times, coming, mitchell, warm, sound
# eOfOrQJWeP0: katt, kev, logo, office, oprah, guy, chairs, cursed, rest, couch, bad, bar, throw, big
# eyUs2JgrV9E: part, peace, piano, million, woman, couple, playing, art, music, played, listing, listen, play, man, iron, museum, virgo, dollar
# fsYZye1Ykao: grey, beach, anatomy, tequila, marble, small, children, black, kitchen, meredith, greys
# gKUyX7cjum4: wallpaper, knew, couple, stp, academy, future, chairs, bedroom, decor, jai, mas, umbrella
# gO_gm74yiUY: chair, inspired, wearing, catriona, earrings, turtles, humble, speak, miss, gay, energy, reminds, piece, waiting, freebritney, said, bret, plants, filipino, ear, universe, deserves
# hJaXjItxL6w: million, illuminati, worth, skate, must, guy, neck, man, mom, first, send, plants, usa, skateboarding, wait, make
# haK2TnmVoT0: smell, kitchen, spa, bedrooms, vagina, candles, maybe, cold
# iY1UnR7z7P0: cancer, bought, comments, keep, pays, art, guy, pay, doping, cheating, built, cheat, man, shame, dope
# jOzaz27K48E: eazy, halsey, zimbabwe, pants, bay, green, rugs, gerald, high, guy, essential, man, kitchen, crib, dope, cozy
# jY3P-f6q-ZI: wallpaper, husband, color, makes, pink, dining
# jwfI8BlFwMw: hope, marriage, toys, family, couple, driving, backwards, big, notice, car, architectural, age, window, squidward, yet, digest, wes, wine, bottle, wife
# kavjzsRtuuA: couch, fun, kind, guy
# l2mtebeR3rA: around, pinterest, kid, husband, shower, fence, wall, mom, pool, age, kids, family, santa, mexican, white
# n50DZvVAulM: painting, couple, curious, art, dining, rent, paintings, bedroom, completely, homey, saving, waiting, kids, sofas, pieces, blur, cozy
# ou3h0twV9TY: painting, laughed, behind, hard, mask, story, lamp, ghost, guy, tell, face, phone, etsy, door, queenie
# pJ8hLOkhl7M: instagrammable, awkward, pink, library, gay, couple, welcome, old, hotel, miami, sales, ken, man, age, vampire, moment, looking, wes, anderson
# qNthtD7KmiA: regretsy, woman, relatable, limes, art, open, bad, carrying, fun, reference, brick, dog, door
# qmHAvgEBnsk: dante, lotus, dad, white, guy, interior, cluttered, american, man, eggs, wife
# rHyIOIstYRA: cat, animals, woman, interesting, bedroom, dita, kitchen, dust, mean, dead, stuffed, white
# sQTGkLW6fwg: set, season, cheryl, fake, netflix, blossom
# uXYyyhUcFg4: drinking, dogs, temple, water, guy, enzo, man, far, sneakers, pool, natural, hair, dog, japanese, humble
# uZDNGVmHxn4: rules, vestibule, interior, man, kitchen, dude, family, dope, new, wife
# ua0-5FZ2Eww: kind, guy, kitchen, makes, youtube, new, jesus, make
# v293iGJ2PVY: jake, couple, sweet, tree, kids, family, feels, fake
# vDD1lhHkGxk: award, parker, york, buddhist, family, nyc, statue, couple, gay, mitch, husband, cam, buddha, closets, man, new, tony, shot, closet
# vGqYP1sKJ2Y: houseplant, rogen, work, guy, smoke, laughs, man, dude, products, kim, lighter
# vvrjhuJrFVc: london, garden, next, incredible, old, rackham, arthur, kept, history, favourite
# vx09_4cEzlM: tunnel, tiger, coolest, crazy, fun, vagina, even, ball, unique
# w4HmK4JCN2U: cottage, gabby, perfect, holiday, magical, cozy
# xT8n0uBIURk: congrats, fak, restaurant, looking, bathroom, bear, food, wait
# xqv0yo_Elj4: bla, accent, light, furniture, master, bedroom, sustainable, bella, vintage, dog, walls
# yKn3Ur6_w3c: ice, whole, literally, let, books, rip, smoke, chuy, everywhere, sauna, feet, cleaning, bravo, chuys
# yjhibJ-OqxE: whole, sign, hear, art, sisters, used, glad, girl, poor, family, said, kardashian, cozy
# zEXXe9Ef_R8: lilly, swan, couple, bedroom, refugees, man, charming, bathroom, entire, carpet, floor, closet, bed, bedwomb
# zPUSDU0hrwE: cottage, low, woman, chastain, color, colors, charming, fan, new, cozy
# za-ogD7nLi8: sunglasses, husband, art, black, bowls, bowl, philippines, makes, gift, balls, make
# zgacuXdzCmw: respect, black, dude, inside, genius, white, congrats, incredible, guy, mansion, trump, hollywood, inspiring, studio, built, sold, man, sided, bar, congratulations, wait
#
# Most common words:
# house: 324
# love: 306
# like: 269
# home: 195
# beautiful: 173
# one: 105
# would: 85
# nice: 82
# looks: 80
# much: 76

# %%
from diffusers import StableDiffusionPipeline
import torch
print("CUDA available:", torch.cuda.is_available())

# Load the model
model_id = "CompVis/stable-diffusion-v1-4"
device = "cuda" if torch.cuda.is_available() else "cpu"

pipe = StableDiffusionPipeline.from_pretrained(model_id)
pipe = pipe.to(device)

prompt = "A futuristic cityscape at sunset"
image = pipe(prompt)["sample"][0]

# Display the generated image
image.show()
# Out:
# CUDA available: False
# /Users/danavolovelsky/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[79], line 13
#      10 pipe = pipe.to(device)
#      12 prompt = "A futuristic cityscape at sunset"
# ---> 13 image = pipe(prompt)["sample"][0]
#      15 # Display the generated image
#      16 image.show()
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/diffusers/pipelines/stable_diffusion/pipeline_stable_diffusion.py:971, in StableDiffusionPipeline.__call__(self, prompt, height, width, num_inference_steps, timesteps, guidance_scale, negative_prompt, num_images_per_prompt, eta, generator, latents, prompt_embeds, negative_prompt_embeds, ip_adapter_image, ip_adapter_image_embeds, output_type, return_dict, cross_attention_kwargs, guidance_rescale, clip_skip, callback_on_step_end, callback_on_step_end_tensor_inputs, **kwargs)
#     968 latent_model_input = self.scheduler.scale_model_input(latent_model_input, t)
#     970 # predict the noise residual
# --> 971 noise_pred = self.unet(
#     972     latent_model_input,
#     973     t,
#     974     encoder_hidden_states=prompt_embeds,
#     975     timestep_cond=timestep_cond,
#     976     cross_attention_kwargs=self.cross_attention_kwargs,
#     977     added_cond_kwargs=added_cond_kwargs,
#     978     return_dict=False,
#     979 )[0]
#     981 # perform guidance
#     982 if self.do_classifier_free_guidance:
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/diffusers/models/unets/unet_2d_condition.py:1281, in UNet2DConditionModel.forward(self, sample, timestep, encoder_hidden_states, class_labels, timestep_cond, attention_mask, cross_attention_kwargs, added_cond_kwargs, down_block_additional_residuals, mid_block_additional_residual, down_intrablock_additional_residuals, encoder_attention_mask, return_dict)
#    1278     upsample_size = down_block_res_samples[-1].shape[2:]
#    1280 if hasattr(upsample_block, "has_cross_attention") and upsample_block.has_cross_attention:
# -> 1281     sample = upsample_block(
#    1282         hidden_states=sample,
#    1283         temb=emb,
#    1284         res_hidden_states_tuple=res_samples,
#    1285         encoder_hidden_states=encoder_hidden_states,
#    1286         cross_attention_kwargs=cross_attention_kwargs,
#    1287         upsample_size=upsample_size,
#    1288         attention_mask=attention_mask,
#    1289         encoder_attention_mask=encoder_attention_mask,
#    1290     )
#    1291 else:
#    1292     sample = upsample_block(
#    1293         hidden_states=sample,
#    1294         temb=emb,
#    1295         res_hidden_states_tuple=res_samples,
#    1296         upsample_size=upsample_size,
#    1297     )
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/diffusers/models/unets/unet_2d_blocks.py:2541, in CrossAttnUpBlock2D.forward(self, hidden_states, res_hidden_states_tuple, temb, encoder_hidden_states, cross_attention_kwargs, upsample_size, attention_mask, encoder_attention_mask)
#    2532         hidden_states = attn(
#    2533             hidden_states,
#    2534             encoder_hidden_states=encoder_hidden_states,
#    (...)
#    2538             return_dict=False,
#    2539         )[0]
#    2540     else:
# -> 2541         hidden_states = resnet(hidden_states, temb)
#    2542         hidden_states = attn(
#    2543             hidden_states,
#    2544             encoder_hidden_states=encoder_hidden_states,
#    (...)
#    2548             return_dict=False,
#    2549         )[0]
#    2551 if self.upsamplers is not None:
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/diffusers/models/resnet.py:371, in ResnetBlock2D.forward(self, input_tensor, temb, *args, **kwargs)
#     368 hidden_states = self.nonlinearity(hidden_states)
#     370 hidden_states = self.dropout(hidden_states)
# --> 371 hidden_states = self.conv2(hidden_states)
#     373 if self.conv_shortcut is not None:
#     374     input_tensor = self.conv_shortcut(input_tensor)
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/torch/nn/modules/conv.py:460, in Conv2d.forward(self, input)
#     459 def forward(self, input: Tensor) -> Tensor:
# --> 460     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/torch/nn/modules/conv.py:456, in Conv2d._conv_forward(self, input, weight, bias)
#     452 if self.padding_mode != 'zeros':
#     453     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     454                     weight, bias, self.stride,
#     455                     _pair(0), self.dilation, self.groups)
# --> 456 return F.conv2d(input, weight, bias, self.stride,
#     457                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
