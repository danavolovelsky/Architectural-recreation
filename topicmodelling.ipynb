# %% [markdown]
# ## Generate Wordclouds

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import ast

# Load the CSV file
df = pd.read_csv('cleaned_comments.csv')

# Get the first 10 unique video IDs
unique_video_ids = df['Video ID'].unique()[:10]

for video_id in unique_video_ids:
    # Filter rows by video ID
    filtered_df = df[df['Video ID'] == video_id]

    # Extract tokens and combine into a single list
    all_tokens = []
    for tokens_str in filtered_df['Tokens']:
        tokens_list = ast.literal_eval(tokens_str)
        all_tokens.extend(tokens_list)

    # Join all tokens into a single string
    text = ' '.join(all_tokens)

    # Generate the word cloud
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Display the word cloud
    plt.figure(figsize=(10, 5))
    plt.title(f'Word Cloud for Video ID: {video_id}')
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 26
#      23 text = ' '.join(all_tokens)
#      25 # Generate the word cloud
# ---> 26 wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
#      28 # Display the word cloud
#      29 plt.figure(figsize=(10, 5))
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/wordcloud/wordcloud.py:642, in WordCloud.generate(self, text)
#     627 def generate(self, text):
#     628     """Generate wordcloud from text.
#     629
#     630     The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     640     self
#     641     """
# --> 642     return self.generate_from_text(text)
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/wordcloud/wordcloud.py:624, in WordCloud.generate_from_text(self, text)
#     607 """Generate wordcloud from text.
#     608
#     609 The input "text" is expected to be a natural text. If you pass a sorted
#    (...)
#     621 self
#     622 """
#     623 words = self.process_text(text)
# --> 624 self.generate_from_frequencies(words)
#     625 return self
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/wordcloud/wordcloud.py:551, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     548         img_array = np.asarray(img_grey) + boolean_mask
#     549     # recompute bottom right
#     550     # the order of the cumsum's is important for speed ?!
# --> 551     occupancy.update(img_array, x, y)
#     552     last_freq = freq
#     554 self.layout_ = list(zip(frequencies, font_sizes, positions,
#     555                         orientations, colors))
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/wordcloud/wordcloud.py:54, in IntegralOccupancyMap.update(self, img_array, pos_x, pos_y)
#      53 def update(self, img_array, pos_x, pos_y):
# ---> 54     partial_integral = np.cumsum(np.cumsum(img_array[pos_x:, pos_y:],
#      55                                            axis=1), axis=0)
#      56     # paste recomputed part into old image
#      57     # if x or y is zero it is a bit annoying
#      58     if pos_x > 0:
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/numpy/core/fromnumeric.py:2586, in cumsum(a, axis, dtype, out)
#    2512 @array_function_dispatch(_cumsum_dispatcher)
#    2513 def cumsum(a, axis=None, dtype=None, out=None):
#    2514     """
#    2515     Return the cumulative sum of the elements along a given axis.
#    2516
#    (...)
#    2584
#    2585     """
# -> 2586     return _wrapfunc(a, 'cumsum', axis=axis, dtype=dtype, out=out)
#
# File ~/miniconda3/envs/big-data-venv/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Merging Comment and Description Tokens
# ## Generating Topics using LDA
# ### Save topics.csv
# Reference:
#
# https://towardsdatascience.com/end-to-end-topic-modeling-in-python-latent-dirichlet-allocation-lda-35ce4ed6b3e0
#
# https://radimrehurek.com/gensim/models/ldamodel.html#

# %%
import pandas as pd
from gensim import corpora, models

comments_df = pd.read_csv('cleaned_comments.csv')
descriptions_df = pd.read_csv('descriptions.csv')

# Merge dataframes by 'Video ID' column
merged_df = pd.merge(comments_df, descriptions_df, on='Video ID')

# Short list of personality showing keywords
personality_keywords = ['personality', 'friend', 'friendly', 'funny']

# List of unique Video IDs
video_ids = merged_df['Video ID'].unique()

topics_data = []

for video_id in video_ids:
    
    # Extract Tokens and remove personality_keywords
    # Convert 'Tokens' string representation of list to actual list
    filtered_comments = merged_df[
        (merged_df['Video ID'] == video_id) & 
        ~merged_df['Tokens'].str.contains('|'.join(personality_keywords))]['Tokens'].apply(eval).tolist()
    
    # Extract Main Description
    filtered_descriptions = merged_df[merged_df['Video ID'] == video_id]['Main Description'].tolist()
    
    # Convert descriptions to list of lists
    filtered_descriptions = [[description] for description in filtered_descriptions]

    # Combine comments and descriptions into a single list
    combined_text = [comment + description for comment, description in zip(filtered_comments, filtered_descriptions)]

    # Creates dictionary from combined data 
    # Eacg word get assigned a unique integer ID
    dictionary = corpora.Dictionary(combined_text)

    # Creates Corpus
    # Big list where each item represents a document, and each document is represented by its 'bag of words'
    corpus = [dictionary.doc2bow(text) for text in combined_text]

    # Train LDA Model
    num_topics = 10  
    lda_model = models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=10)
    
    # Save topics to the empty DataFrame
    for topic in lda_model.print_topics():
        topics_data.append({'Video ID': video_id, 'Topic': topic})
        
    # Print topics 
    print(f"Topics for Video ID: {video_id}")
    for topic in lda_model.print_topics():
        print(topic)
        
# Convert list of topics to a DataFrame
topics_df = pd.DataFrame(topics_data)

topics_df.to_csv('topics.csv', index=False)
# Out:
# Topics for Video ID: kavjzsRtuuA
# (0, '0.089*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.015*"house" + 0.013*"cold" + 0.012*"like" + 0.012*"plunge" + 0.010*"faster" + 0.010*"emails" + 0.010*"going" + 0.010*"write" + 0.008*"seems"')
# (1, '0.100*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.019*"one" + 0.014*"lucky" + 0.014*"know" + 0.013*"best" + 0.010*"love" + 0.008*"genuine" + 0.008*"gomez" + 0.008*"guy" + 0.007*"back"')
# (2, '0.124*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.017*"lol" + 0.016*"see" + 0.015*"best" + 0.015*"want" + 0.015*"amazing" + 0.014*"energy" + 0.012*"wow" + 0.012*"art" + 0.010*"happy"')
# (3, '0.173*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.075*"love" + 0.043*"house" + 0.017*"cool" + 0.014*"guy" + 0.012*"dude" + 0.010*"know" + 0.009*"sweet" + 0.008*"beautiful" + 0.008*"like"')
# (4, '0.056*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.011*"get" + 0.008*"would" + 0.008*"lmao" + 0.008*"okay" + 0.007*"nobody" + 0.007*"candies" + 0.006*"bro" + 0.005*"house" + 0.005*"seems"')
# (5, '0.140*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.025*"like" + 0.017*"one" + 0.015*"house" + 0.013*"love" + 0.011*"people" + 0.009*"fun" + 0.008*"lol" + 0.007*"come" + 0.007*"shower"')
# (6, '0.115*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.027*"like" + 0.015*"saying" + 0.014*"vibe" + 0.011*"see" + 0.010*"time" + 0.009*"lol" + 0.009*"loves" + 0.009*"guy" + 0.009*"love"')
# (7, '0.094*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.015*"guy" + 0.012*"room" + 0.011*"could" + 0.010*"earth" + 0.010*"best" + 0.009*"cool" + 0.007*"ever" + 0.007*"wen" + 0.007*"one"')
# (8, '0.127*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.054*"love" + 0.010*"people" + 0.010*"room" + 0.008*"beautiful" + 0.007*"would" + 0.005*"much" + 0.005*"like" + 0.005*"thank" + 0.005*"still"')
# (9, '0.149*"[\'ad\', \'welcomed\', \'hit\', \'music\', \'producer\', \'tour\', \'home\', \'los\', \'built\', \'spacious\', \'home\', \'throw\', \'away\', \'recording\', \'despite\', \'proximity\', \'design\', \'brief\', \'help\', \'rachel\', \'leigh\', \'ward\', \'dana\', \'vitrano\', \'bonvivant\', \'interiors\', \'designer\', \'keefe\', \'butler\', \'studio\', \'resulting\', \'space\', \'eclectic\', \'playful\', \'plenty\', \'kick\', \'back\', \'relax\', \'family\', \'including\', \'superstar\', \'girlfriend\', \'selena\', \'red\', \'velvet\', \'movie\', \'theatre\', \'candy\', \'room\', \'dressing\', \'home\', \'full\', \'personality\', \'fun\', \'know\', \'house\', \'friend\', \'told\', \'love\', \'coming\', \'house\', \'feel\', \'like\', \'let\', \'go\', \'true\', \'exactly\', \'going\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'see\', \'la\', \'home\', \'artwork\', \'courtesy\', \'night\', \'gallery\', \'impossible\', \'viscosity\', \'faig\', \'ahmed\', \'courtesy\', \'artist\', \'sapar\', \'untitled\', \'boxer\', \'martin\', \'wong\', \'foundation\', \'courtesy\', \'martin\', \'wong\', \'foundation\', \'new\', \'york\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.042*"guy" + 0.042*"seems" + 0.037*"like" + 0.027*"house" + 0.017*"nice" + 0.016*"love" + 0.012*"awesome" + 0.011*"see" + 0.011*"much"')
# Topics for Video ID: XxPPdlo72ho
# (0, '0.083*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.038*"house" + 0.017*"cozy" + 0.016*"need" + 0.014*"warm" + 0.012*"much" + 0.011*"obsessed" + 0.009*"looks" + 0.009*"space" + 0.009*"must"')
# (1, '0.107*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.027*"house" + 0.024*"gorgeous" + 0.017*"cozy" + 0.013*"normal" + 0.011*"much" + 0.011*"looks" + 0.010*"fireplace" + 0.010*"wow" + 0.010*"love"')
# (2, '0.113*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.052*"beautiful" + 0.034*"house" + 0.018*"like" + 0.017*"love" + 0.015*"cozy" + 0.011*"cool" + 0.011*"still" + 0.009*"would" + 0.009*"want"')
# (3, '0.088*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.043*"omg" + 0.037*"like" + 0.014*"cute" + 0.013*"kind" + 0.011*"though" + 0.008*"tile" + 0.008*"cottage" + 0.008*"taste" + 0.007*"nice"')
# (4, '0.181*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.078*"love" + 0.051*"house" + 0.017*"like" + 0.014*"cozy" + 0.011*"style" + 0.010*"looks" + 0.009*"favorite" + 0.009*"beautiful" + 0.008*"cute"')
# (5, '0.120*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.045*"house" + 0.034*"love" + 0.018*"absolutely" + 0.015*"like" + 0.014*"everything" + 0.012*"dolls" + 0.009*"would" + 0.009*"vibe" + 0.008*"watching"')
# (6, '0.097*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.030*"covers" + 0.028*"cord" + 0.014*"fire" + 0.012*"house" + 0.012*"would" + 0.012*"like" + 0.009*"hazard" + 0.009*"let" + 0.009*"lestari"')
# (7, '0.111*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.039*"love" + 0.033*"doll" + 0.024*"one" + 0.015*"ship" + 0.014*"chandelier" + 0.013*"wall" + 0.012*"favorite" + 0.011*"like" + 0.010*"style"')
# (8, '0.136*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.052*"house" + 0.041*"love" + 0.019*"want" + 0.016*"son" + 0.016*"wow" + 0.016*"beautiful" + 0.013*"cozy" + 0.012*"like" + 0.010*"charming"')
# (9, '0.122*"[\'ad\', \'welcomed\', \'tour\', \'charming\', \'los\', \'angeles\', \'horror\', \'star\', \'son\', \'moved\', \'new\', \'enlisted\', \'pierce\', \'ward\', \'work\', \'magic\', \'rich\', \'luxurious\', \'velvets\', \'pair\', \'vintage\', \'furniture\', \'cozy\', \'environment\', \'kick\', \'back\', \'excited\', \'idea\', \'making\', \'dollhouse\', \'extensive\', \'doll\', \'home\', \'become\', \'new\', \'chapter\', \'new\', \'happier\', \'space\', \'picture\', \'day\', \'moved\', \'holding\', \'sunny\', \'california\', \'front\', \'blue\', \'door\', \'new\', \'remember\', \'feeling\', \'like\', \'exactly\', \'need\', \'see\', \'la\', \'home\', \'shop\', \'pieces\', \'inspired\', \'la\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'graham\', \'henry\', \'diltz\', \'henry\', \'diltz\', \'photography\', \'nyc\', \'maripol\', \'mitchell\', \'pool\', \'master\', \'photographer\', \'norman\', \'seeff\', \'meg\', \'sutton\', \'director\', \'grant\', \'bell\', \'leticia\', \'villarinho\', \'skylar\', \'economy\', \'line\', \'buscemi\', \'associate\', \'brandon\', \'fuhr\', \'production\', \'melissa\', \'heber\', \'production\', \'fernando\', \'davila\', \'talent\', \'tracy\', \'shaffer\', \'camera\', \'anderson\', \'audio\', \'cornett\', \'production\', \'fernando\', \'barajas\', \'hair\', \'bridget\', \'jenna\', \'anton\', \'post\', \'production\', \'montague\', \'post\', \'production\', \'holly\', \'frew\', \'supervising\', \'christina\', \'mankellow\', \'fynn\', \'lithgow\', \'eid\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.042*"love" + 0.031*"dolls" + 0.026*"house" + 0.019*"loved" + 0.016*"know" + 0.015*"best" + 0.013*"pool" + 0.013*"one" + 0.012*"seen"')
# Topics for Video ID: VylU-ueLA_g
# (0, '0.104*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.032*"house" + 0.013*"guy" + 0.012*"like" + 0.011*"rich" + 0.011*"never" + 0.011*"everything" + 0.007*"seems" + 0.007*"need" + 0.007*"sure"')
# (1, '0.155*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.041*"minimalist" + 0.022*"house" + 0.013*"love" + 0.010*"like" + 0.009*"yes" + 0.008*"lol" + 0.007*"youtube" + 0.007*"cool" + 0.006*"know"')
# (2, '0.125*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.039*"papa" + 0.028*"house" + 0.011*"love" + 0.011*"like" + 0.009*"beautiful" + 0.009*"thought" + 0.008*"well" + 0.008*"needs" + 0.007*"channel"')
# (3, '0.054*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.012*"must" + 0.012*"lol" + 0.008*"nice" + 0.008*"making" + 0.008*"announcement" + 0.008*"neff" + 0.008*"lmao" + 0.008*"video" + 0.008*"otk"')
# (4, '0.128*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.021*"house" + 0.016*"kitchen" + 0.014*"nice" + 0.013*"room" + 0.011*"one" + 0.011*"papa" + 0.011*"made" + 0.011*"austin" + 0.009*"wow"')
# (5, '0.106*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.043*"love" + 0.023*"like" + 0.015*"taste" + 0.014*"guy" + 0.012*"got" + 0.011*"ice" + 0.011*"looks" + 0.007*"day" + 0.007*"ugly"')
# (6, '0.085*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.035*"know" + 0.024*"would" + 0.019*"house" + 0.018*"love" + 0.014*"first" + 0.012*"guy" + 0.012*"lol" + 0.010*"like" + 0.009*"ago"')
# (7, '0.086*"[\'ad\', \'welcomed\', \'chef\', \'youtuber\', \'tour\', \'minimalist\', \'home\', \'often\', \'said\', \'kitchen\', \'heart\', \'nearly\', \'million\', \'subscribers\', \'following\', \'gastronomical\', \'youtube\', \'kitchen\', \'youtube\', \'knives\', \'prized\', \'proudly\', \'displayed\', \'along\', \'magnetized\', \'italian\', \'carrara\', \'countertops\', \'add\', \'luxurious\', \'style\', \'function\', \'though\', \'maybe\', \'beautiful\', \'beat\', \'performance\', \'organized\', \'perfection\', \'save\', \'time\', \'thought\', \'could\', \'cooking\', \'number\', \'one\', \'thing\', \'kitchen\', \'size\', \'nice\', \'organize\', \'operate\', \'actually\', \'enjoy\', \'process\', \'think\', \'think\', \'see\', \'austin\', \'home\', \'shop\', \'home\', \'buy\', \'something\', \'retail\', \'earn\', \'affiliate\', \'artwork\', \'abstraction\', \'ca\', \'nicholas\', \'ali\', \'duo\', \'luto\', \'want\', \'even\', \'subscribe\', \'magazine\', \'get\', \'free\', \'tote\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\']" + 0.016*"much" + 0.015*"like" + 0.015*"house" + 0.012*"see" + 0.010*"guy" + 0.010*"marble" + 0.008*"used" + 0.008*"fan" + 0.007*"love"')
# ...
# Topics for Video ID: KyI8i1-cN8s
# (0, '0.207*"[\'episode\', \'welcomes\', \'architectural\', \'digest\', \'man\', \'home\', \'away\', \'home\', \'see\', \'photos\', \'full\', \'interview\', \'confesses\', \'big\', \'book\', \'guy\', \'loves\', \'star\', \'brooklyn\', \'everybody\', \'hates\', \'chris\', \'throws\', \'quick\', \'plug\', \'berry\', \'line\', \'actor\', \'incredible\', \'assortment\', \'boxing\', \'gloves\', \'sugar\', \'harlem\', \'globetrotters\', \'idiocracy\', \'movie\', \'poster\', \'shepard\', \'lip\', \'sync\', \'battle\', \'championship\', \'belt\', \'among\', \'also\', \'shares\', \'influential\', \'inspirations\', \'reveals\', \'couch\', \'bookshelf\', \'turns\', \'logo\', \'furniture\', \'collection\', \'company\', \'amen\', \'former\', \'host\', \'funniest\', \'fails\', \'presents\', \'custom\', \'gaming\', \'pc\', \'stick\', \'old\', \'spice\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\', \'inside\', \'la\', \'man\', \'cave\', \'open\', \'door\', \'architectural\', \'digest\']" + 0.138*"love" + 0.044*"guy" + 0.041*"dude" + 0.023*"best" + 0.021*"much" + 0.020*"man" + 0.015*"energy" + 0.015*"life" + 0.014*"dad"')
# (1, '0.102*"[\'episode\', \'welcomes\', \'architectural\', \'digest\', \'man\', \'home\', \'away\', \'home\', \'see\', \'photos\', \'full\', \'interview\', \'confesses\', \'big\', \'book\', \'guy\', \'loves\', \'star\', \'brooklyn\', \'everybody\', \'hates\', \'chris\', \'throws\', \'quick\', \'plug\', \'berry\', \'line\', \'actor\', \'incredible\', \'assortment\', \'boxing\', \'gloves\', \'sugar\', \'harlem\', \'globetrotters\', \'idiocracy\', \'movie\', \'poster\', \'shepard\', \'lip\', \'sync\', \'battle\', \'championship\', \'belt\', \'among\', \'also\', \'shares\', \'influential\', \'inspirations\', \'reveals\', \'couch\', \'bookshelf\', \'turns\', \'logo\', \'furniture\', \'collection\', \'company\', \'amen\', \'former\', \'host\', \'funniest\', \'fails\', \'presents\', \'custom\', \'gaming\', \'pc\', \'stick\', \'old\', \'spice\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\', \'inside\', \'la\', \'man\', \'cave\', \'open\', \'door\', \'architectural\', \'digest\']" + 0.052*"big" + 0.034*"got" + 0.032*"would" + 0.020*"one" + 0.020*"used" + 0.019*"power" + 0.019*"strong" + 0.018*"sometimes" + 0.018*"sexually"')
# (2, '0.054*"[\'episode\', \'welcomes\', \'architectural\', \'digest\', \'man\', \'home\', \'away\', \'home\', \'see\', \'photos\', \'full\', \'interview\', \'confesses\', \'big\', \'book\', \'guy\', \'loves\', \'star\', \'brooklyn\', \'everybody\', \'hates\', \'chris\', \'throws\', \'quick\', \'plug\', \'berry\', \'line\', \'actor\', \'incredible\', \'assortment\', \'boxing\', \'gloves\', \'sugar\', \'harlem\', \'globetrotters\', \'idiocracy\', \'movie\', \'poster\', \'shepard\', \'lip\', \'sync\', \'battle\', \'championship\', \'belt\', \'among\', \'also\', \'shares\', \'influential\', \'inspirations\', \'reveals\', \'couch\', \'bookshelf\', \'turns\', \'logo\', \'furniture\', \'collection\', \'company\', \'amen\', \'former\', \'host\', \'funniest\', \'fails\', \'presents\', \'custom\', \'gaming\', \'pc\', \'stick\', \'old\', \'spice\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\', \'inside\', \'la\', \'man\', \'cave\', \'open\', \'door\', \'architectural\', \'digest\']" + 0.039*"house" + 0.013*"white" + 0.011*"family" + 0.010*"design" + 0.009*"chicks" + 0.009*"must" + 0.008*"show" + 0.008*"literally" + 0.007*"worth"')
# (3, '0.073*"[\'episode\', \'welcomes\', \'architectural\', \'digest\', \'man\', \'home\', \'away\', \'home\', \'see\', \'photos\', \'full\', \'interview\', \'confesses\', \'big\', \'book\', \'guy\', \'loves\', \'star\', \'brooklyn\', \'everybody\', \'hates\', \'chris\', \'throws\', \'quick\', \'plug\', \'berry\', \'line\', \'actor\', \'incredible\', \'assortment\', \'boxing\', \'gloves\', \'sugar\', \'harlem\', \'globetrotters\', \'idiocracy\', \'movie\', \'poster\', \'shepard\', \'lip\', \'sync\', \'battle\', \'championship\', \'belt\', \'among\', \'also\', \'shares\', \'influential\', \'inspirations\', \'reveals\', \'couch\', \'bookshelf\', \'turns\', \'logo\', \'furniture\', \'collection\', \'company\', \'amen\', \'former\', \'host\', \'funniest\', \'fails\', \'presents\', \'custom\', \'gaming\', \'pc\', \'stick\', \'old\', \'spice\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\', \'inside\', \'la\', \'man\', \'cave\', \'open\', \'door\', \'architectural\', \'digest\']" + 0.034*"every" + 0.030*"played" + 0.028*"rams" + 0.020*"overwatch" + 0.019*"plays" + 0.017*"gets" + 0.017*"coming" + 0.017*"impossible" + 0.016*"come"')
# (4, '0.155*"[\'episode\', \'welcomes\', \'architectural\', \'digest\', \'man\', \'home\', \'away\', \'home\', \'see\', \'photos\', \'full\', \'interview\', \'confesses\', \'big\', \'book\', \'guy\', \'loves\', \'star\', \'brooklyn\', \'everybody\', \'hates\', \'chris\', \'throws\', \'quick\', \'plug\', \'berry\', \'line\', \'actor\', \'incredible\', \'assortment\', \'boxing\', \'gloves\', \'sugar\', \'harlem\', \'globetrotters\', \'idiocracy\', \'movie\', \'poster\', \'shepard\', \'lip\', \'sync\', \'battle\', \'championship\', \'belt\', \'among\', \'also\', \'shares\', \'influential\', \'inspirations\', \'reveals\', \'couch\', \'bookshelf\', \'turns\', \'logo\', \'furniture\', \'collection\', \'company\', \'amen\', \'former\', \'host\', \'funniest\', \'fails\', \'presents\', \'custom\', \'gaming\', \'pc\', \'stick\', \'old\', \'spice\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\', \'inside\', \'la\', \'man\', \'cave\', \'open\', \'door\', \'architectural\', \'digest\']" + 0.023*"guy" + 0.018*"day" + 0.017*"black" + 0.017*"cool" + 0.017*"man" + 0.015*"beautiful" + 0.014*"name" + 0.012*"clean" + 0.012*"eric"')
# (5, '0.084*"hate" + 0.045*"white" + 0.036*"killed" + 0.036*"google" + 0.035*"apple" + 0.035*"podcast" + 0.034*"anti" + 0.034*"within" + 0.021*"[\'episode\', \'welcomes\', \'architectural\', \'digest\', \'man\', \'home\', \'away\', \'home\', \'see\', \'photos\', \'full\', \'interview\', \'confesses\', \'big\', \'book\', \'guy\', \'loves\', \'star\', \'brooklyn\', \'everybody\', \'hates\', \'chris\', \'throws\', \'quick\', \'plug\', \'berry\', \'line\', \'actor\', \'incredible\', \'assortment\', \'boxing\', \'gloves\', \'sugar\', \'harlem\', \'globetrotters\', \'idiocracy\', \'movie\', \'poster\', \'shepard\', \'lip\', \'sync\', \'battle\', \'championship\', \'belt\', \'among\', \'also\', \'shares\', \'influential\', \'inspirations\', \'reveals\', \'couch\', \'bookshelf\', \'turns\', \'logo\', \'furniture\', \'collection\', \'company\', \'amen\', \'former\', \'host\', \'funniest\', \'fails\', \'presents\', \'custom\', \'gaming\', \'pc\', \'stick\', \'old\', \'spice\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\', \'inside\', \'la\', \'man\', \'cave\', \'open\', \'door\', \'architectural\', \'digest\']" + 0.008*"perfect"')
# (6, '0.130*"[\'episode\', \'welcomes\', \'architectural\', \'digest\', \'man\', \'home\', \'away\', \'home\', \'see\', \'photos\', \'full\', \'interview\', \'confesses\', \'big\', \'book\', \'guy\', \'loves\', \'star\', \'brooklyn\', \'everybody\', \'hates\', \'chris\', \'throws\', \'quick\', \'plug\', \'berry\', \'line\', \'actor\', \'incredible\', \'assortment\', \'boxing\', \'gloves\', \'sugar\', \'harlem\', \'globetrotters\', \'idiocracy\', \'movie\', \'poster\', \'shepard\', \'lip\', \'sync\', \'battle\', \'championship\', \'belt\', \'among\', \'also\', \'shares\', \'influential\', \'inspirations\', \'reveals\', \'couch\', \'bookshelf\', \'turns\', \'logo\', \'furniture\', \'collection\', \'company\', \'amen\', \'former\', \'host\', \'funniest\', \'fails\', \'presents\', \'custom\', \'gaming\', \'pc\', \'stick\', \'old\', \'spice\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\', \'inside\', \'la\', \'man\', \'cave\', \'open\', \'door\', \'architectural\', \'digest\']" + 0.030*"things" + 0.022*"kids" + 0.020*"sell" + 0.017*"give" + 0.016*"fun" + 0.016*"dead" + 0.014*"crew" + 0.014*"going" + 0.013*"built"')
# (7, '0.164*"[\'episode\', \'welcomes\', \'architectural\', \'digest\', \'man\', \'home\', \'away\', \'home\', \'see\', \'photos\', \'full\', \'interview\', \'confesses\', \'big\', \'book\', \'guy\', \'loves\', \'star\', \'brooklyn\', \'everybody\', \'hates\', \'chris\', \'throws\', \'quick\', \'plug\', \'berry\', \'line\', \'actor\', \'incredible\', \'assortment\', \'boxing\', \'gloves\', \'sugar\', \'harlem\', \'globetrotters\', \'idiocracy\', \'movie\', \'poster\', \'shepard\', \'lip\', \'sync\', \'battle\', \'championship\', \'belt\', \'among\', \'also\', \'shares\', \'influential\', \'inspirations\', \'reveals\', \'couch\', \'bookshelf\', \'turns\', \'logo\', \'furniture\', \'collection\', \'company\', \'amen\', \'former\', \'host\', \'funniest\', \'fails\', \'presents\', \'custom\', \'gaming\', \'pc\', \'stick\', \'old\', \'spice\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\', \'inside\', \'la\', \'man\', \'cave\', \'open\', \'door\', \'architectural\', \'digest\']" + 0.032*"world" + 0.030*"loves" + 0.030*"one" + 0.029*"want" + 0.027*"yogurt" + 0.022*"look" + 0.019*"warcraft" + 0.018*"time" + 0.017*"favorite"')
# (8, '0.122*"[\'episode\', \'welcomes\', \'architectural\', \'digest\', \'man\', \'home\', \'away\', \'home\', \'see\', \'photos\', \'full\', \'interview\', \'confesses\', \'big\', \'book\', \'guy\', \'loves\', \'star\', \'brooklyn\', \'everybody\', \'hates\', \'chris\', \'throws\', \'quick\', \'plug\', \'berry\', \'line\', \'actor\', \'incredible\', \'assortment\', \'boxing\', \'gloves\', \'sugar\', \'harlem\', \'globetrotters\', \'idiocracy\', \'movie\', \'poster\', \'shepard\', \'lip\', \'sync\', \'battle\', \'championship\', \'belt\', \'among\', \'also\', \'shares\', \'influential\', \'inspirations\', \'reveals\', \'couch\', \'bookshelf\', \'turns\', \'logo\', \'furniture\', \'collection\', \'company\', \'amen\', \'former\', \'host\', \'funniest\', \'fails\', \'presents\', \'custom\', \'gaming\', \'pc\', \'stick\', \'old\', \'spice\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\', \'inside\', \'la\', \'man\', \'cave\', \'open\', \'door\', \'architectural\', \'digest\']" + 0.036*"jayztwocents" + 0.025*"first" + 0.025*"bed" + 0.022*"job" + 0.021*"light" + 0.019*"see" + 0.018*"wife" + 0.017*"made" + 0.015*"video"')
# (9, '0.164*"[\'episode\', \'welcomes\', \'architectural\', \'digest\', \'man\', \'home\', \'away\', \'home\', \'see\', \'photos\', \'full\', \'interview\', \'confesses\', \'big\', \'book\', \'guy\', \'loves\', \'star\', \'brooklyn\', \'everybody\', \'hates\', \'chris\', \'throws\', \'quick\', \'plug\', \'berry\', \'line\', \'actor\', \'incredible\', \'assortment\', \'boxing\', \'gloves\', \'sugar\', \'harlem\', \'globetrotters\', \'idiocracy\', \'movie\', \'poster\', \'shepard\', \'lip\', \'sync\', \'battle\', \'championship\', \'belt\', \'among\', \'also\', \'shares\', \'influential\', \'inspirations\', \'reveals\', \'couch\', \'bookshelf\', \'turns\', \'logo\', \'furniture\', \'collection\', \'company\', \'amen\', \'former\', \'host\', \'funniest\', \'fails\', \'presents\', \'custom\', \'gaming\', \'pc\', \'stick\', \'old\', \'spice\', \'still\', \'subscribed\', \'architectural\', \'digest\', \'architectural\', \'digest\', \'leading\', \'international\', \'design\', \'architectural\', \'digest\', \'features\', \'articles\', \'videos\', \'best\', \'inside\', \'la\', \'man\', \'cave\', \'open\', \'door\', \'architectural\', \'digest\']" + 0.055*"like" + 0.039*"man" + 0.028*"guy" + 0.022*"nice" + 0.018*"place" + 0.016*"damn" + 0.014*"humble" + 0.014*"never" + 0.013*"racist"')

# %% [markdown]
# ## Clean and Parse topics
# ### Save top_5_topics.csv

# %%
import pandas as pd
import ast

# Read the topics.csv file into a DataFrame
topics_df = pd.read_csv('topics.csv')

# Convert the 'Topic' column to string type
topics_df['Topic'] = topics_df['Topic'].astype(str)

# Function to clean and parse the topic strings
def clean_and_parse_topic(topic_content):
    # Remove leading and following parentheses, splits string after first comma, Keeps the second part
        topic_content = topic_content.strip("()")
        parts = topic_content.split(", ", 1)
        if len(parts) > 1:
            topic_content = parts[1]
        
        # Replace specific problematic characters
        cleaned_content = topic_content.replace('""', '').replace("'", "").replace('\\', '')
        
        # Extracts the description weight
        desc_weight = float(cleaned_content.split("*")[0])
        
        # Extracts the topics
        topics = []
        parts = cleaned_content.split(" + ")
        for part in parts:
            if '*' in part:
                _, topic = part.split('*', 1)
                topic = topic.strip()
                topics.append(topic)
        return desc_weight, topics

# Group by 'Video ID'
grouped = topics_df.groupby('Video ID')

# Function to extract top 5 topics based on weights
def get_top_5_topics(group):
    topics = []
    for _, row in group.iterrows():
        desc_weight, topic_info = clean_and_parse_topic(row['Topic'])
        if topic_info:
            topics.append((desc_weight, topic_info))
    # Sort topics based on description weights and select the top 5
    top_5_topics = sorted(topics, key=lambda x: x[0], reverse=True)[:5]
    return [(weight, topic) for weight, topic in top_5_topics]


# Apply the function to each group and sets new column names
result = grouped.apply(get_top_5_topics).reset_index()
result.columns = ['Video ID', 'Top 5 Topics']

# Write the result to a new CSV file
result.to_csv('top_5_topics.csv', index=False)
# Out:
# /var/folders/qv/dfs9xlmx52x51qbbcp3zlfj00000gn/T/ipykernel_90151/496021732.py:55: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result = grouped.apply(get_top_5_topics).reset_index()

# %% [markdown]
# ## Clean Final Top 5 topics
# ### Save cleaned_top_5_topics.csv
# Reference:
#
# https://www.analyticsvidhya.com/blog/2021/08/python-tutorial-working-with-csv-file-for-data-science/

# %%
import csv
import ast

# Open input and output files
with open('top_5_topics.csv', 'r', newline='', encoding='utf-8') as input_file, \
     open('cleaned_top_5_topics.csv', 'w', newline='', encoding='utf-8') as output_file:
   
    reader = csv.reader(input_file)
    writer = csv.writer(output_file)

    writer.writerow(['Video ID', 'Weight', 'Topics']) # Header

    next(reader) # Skip header

    # Iterate over each row in the input file
    for row in reader:
        video_id = row[0]  # Extract video ID
        topics = eval(row[1])  # Convert string representation of topics to a list

        # Iterate over each topic in the list
        for weight, topic_list in topics:
            # Filter out topics that start or end with square brackets
            topic_list = [topic for topic in topic_list if not topic.startswith('[') and not topic.endswith(']')]
            topic_string = ', '.join(topic_list)  # Convert topic list to a string
            writer.writerow([video_id, weight, topic_string])
# Out:
# Cleaning complete. Output saved to cleaned_top_5_topics.csv

# %% [markdown]
# ## Further processing

# %%
import pandas as pd
import ast

# Read the CSV file
df = pd.read_csv("cleaned_top_5_topics.csv")

def process_topics(topics): 
    # Remove the triple quotes and split the string into two parts
    parts = topics.replace('"""', '').split('", "', 1)
    
    # Check if there are two parts
    if len(parts) == 2:        

        return parts[1]

# Apply to the Topics column
df['Topics'] = df['Topics'].apply(process_topics)


df.to_csv("cleaned_top_5_topics.csv", index=False)

# %% [markdown]
# ## Counting topic words and final dataframe
# ### Save sd_topics

# %%
from collections import defaultdict, Counter

df = pd.read_csv("cleaned_top_5_topics.csv")

# Store topics for each video
topics_dict = defaultdict(set)

# Counts frequency of each word
word_counter = Counter()

remove_words = ["love", "loved", "lovely", "house", "home", "like", "gorgeous", "amazing", "beautiful", "ever", 
                "lol", "omg", "nice", "like", "cool", "best", "looks", "would", "one", "much", "room",
                "look", "wow", "see", "good", "know", "stunning", "people", "want", "style", "seen", "place", 
                "video", "taste", "cute", "everything", "well", "absolutely", "get", "space", "anyone", "tour",
                "apartment", "money", "design", "vibe", "could", "seems", "way", "favorite", "happy", "rich", "thank",
                "two", "still", "need", "every", "feel", "show", "many", "got", "damn", "time", "please", "thought", "blurred",
                "homes", "voice", "someone", "yes", "actually", "done", "god", "life", "going", "ariel", "pretty", "laugh", "person",
                "together", "though", "always", "thing", "vibes", "also", "day", "else", "episode", "say", "que", "think", "melo", "little",
                "loves", "awesome", "never", "rooms", "proud", "riverdale", "job", "queen", "watch", "sharing", "thanks", "lady", "married", 
                "right", "baby", "houses"]

# Iteration over each row in the dataframe
for index, row in df.iterrows():
    video_id, weight, topics = row['Video ID'], row['Weight'], row['Topics']
    # Remove extra quotation marks
    topics = topics.replace('"', '')
    # Splits topics into individual words
    topics = topics.split(", ")
    
    word_counter.update(topics)
    
    topics = [topic for topic in topics if topic not in remove_words]
    topics_dict[video_id].update(topics)
    
sd_topics = pd.DataFrame(columns=['Video ID', 'Topics'])

# Print the results
for video_id, topics in topics_dict.items():
    print(f"{video_id}: {', '.join(topics)}")
    # Add results to new dataframe
    new_row = pd.DataFrame({'Video ID': [video_id], 'Topics': [', '.join(topics)]})
    sd_topics = pd.concat([sd_topics, new_row], ignore_index=True)
        
sd_topics.to_csv('sd_topics.csv', index=False)

print("\nMost common words:")
for word, count in word_counter.most_common(150):  
    print(f"{word}: {count}")
# Out:
# -TeeIEh2IE8: remember, body, keep, cold, gallery, second, art, trophies, times, trophy, museum, chair, trash, elmo, door, nepal, unique, magazine
# -zkOLKMiX9c: pepper, body, art, woman, old, white
# 0K9eZCW-lvc: body, sweet, kitchen, tate, cozy, dress, something
# 0_BEwbnmRZ4: panic, man, humor, jazzy, monotone, hilarious, sounds, leave, spanish, guy
# 5WH-PSs9hI8: mama, fracking, joy, drag, color, black, disco, white, closet
# 5vNoHwgoIjw: mcguire, sons, dress, lizzie, girl, samsung, chickens, fish, kids, chicken, coop
# 5zvsAwsEwPg: joy, couple, wife, story, sweet
# 7R2RyqU4hjI: needs, accent, couple, castle, irish, catherine, haunted, garden, pot, mcnulty, family, ancestors, title, wonderful
# 7Z76MiQv0zg: magnolia, attic, arwen, asmr, soothing, soul, sword, sweet, lotr, woman, display, tree
# 7cGmj0AR3z8: handsome, quality, statue, casa, colombian, creepy, bedroom, hot, jersey, coffee, colombia, neymar, guy
# 80z6drP0NY8: decor, furniture, first, mind, miss, come, older, man, player, jordan, nba, future, kids, basketball, vacation, court, hard, guy
# 8MkcEzfyCFM: collection, dope, brother, player, art, piece, respect, salute, crib, guy
# 9KapEXWynrA: feels, wrong, deal, things, yummy, forever, texture, wondering, frame, wall, three, art, far, large, painting, elena, kitchen, buy
# 9OvibwfflDg: accent, una, crystal, learn, perfection, exquisite, woman, birds, cook, latin, closet
# 9p9sGtV4UoU: etsy, cozy, outfit, art, bathroom, cat, toilet, kids, upstate, celebrities, dead, oleander
# ATGZ58IRwfE: girl, traffic, needs, poppy, couple, gay, tree, ricky, kitchen, family, new, sad, play, daughter
# AkTkUOOCZ-w: shoes, bunk, bed, everybody, couple, age, wife, family, cozy, ice
# AwhBTrzzqeg: red, coolest, dog, girl, movie, table, bedroom, soothing, neighbors, bamboo, book, green, kitchen, shades, limes
# Axg27gwEqCE: remember, girl, sonata, mozart, obsessed, beethoven, bathroom, far, gary, garden, celebrity
# BDA6rPA0Fcs: barney, flip, scooter, suit, couple, art, gay, book, bar, kitchen, nph
# D-qQneOnJl0: finally, bad, warm, couple, meth, lab, open, pinkman, todd, minerals, cooking, stone, cozy, cabin, cook, white
# D_gkHpZ2oRI: books, furniture, authentic, boring, definitely, garden, fun, honest
# EB_Z-8kBNm8: piano, blue, amy, scottish, pond, charming, obsessed, kitchen, cozy, door, fun, comic, yorkshire
# EobMnSpjfTU: world, made, super, sense, gay, couch, sweet, shirt, melbourne, cozy, part, imagine
# ExTP2rYqguE: feels, tell, let, ross, couple, favourite, bathroom, mike, perfect, rachel, claire
# FIDsKWis3jo: big, built, girl, particular, wood, view, smog, cozy, dress
# GiYK_6FxNts: dog, edmonton, personal, cold, black, boring, couple, modern, definitely, interior, hotel, leonard, cozy, inside, white
# HphRKCxIK_Q: picture, line, shot, husband, watching, says, jumpsuit, pics, naked, kids, family, wearing, woman, spanish, zip, brazilian, daughter
# IxlzRwNX63A: collection, elegance, classy, artwork, elegant, art, dressing, woman, closet
# JKUWL85Betk: decor, bad, girl, pictures, boring, black, color, gold, interior, con, sorry, plural, sheeps, meh, whole, sheep, model, white
# Jzqu48uup54: america, politics, eyes, coke, monica, word, aside, oval, president, merry, office, rug, believe, clinton, dude, takes, christmas, youtube, guy, white
# KHfP3InQc94: food, years, kourtney, kardashian, dude, candle, black, calm, kourt, vegan, family, cozy, guy, kourtneys
# KIqQ0gowzt4: luxury, cribs, furniture, malindi, resort, kenyan, age, hotel, kenya, whole, african, africa, villa, happens, rains, believe, woman
# KuYsILv6Fd0: children, safe, couple, poppy, kitchen, new, kids, family
# KyI8i1-cN8s: made, wallpaper, energy, saw, computer, let, things, cave, dad, light, super, wife, sell, respect, yogurt, bed, office, jayztwocents, clean, humble, away, man, dude, even, around, kids, guy
# Li8ubUzLB90: finally, yard, first, victoria, modern, family, adu, chicken, sure, mitchell, cam
# LpVraZRIjrY: leather, wallpaper, art, cloud, farmhouse, kitchen, sure, fun, gucci, dogs, unique
# NXrwxbxeqCE: beach, marble, dog, small, bathroom, stove, kitchen, cozy, dogs
# P-7mzzWtnVQ: mom, fluffing, paris, trees, fluffer, bowl, christmas, tree
# PKAM4M9OET8: beata, shower, stuff, bedroom, art, garden, eclectic, unique
# PWnDS45iDj4: pants, big, cars, brand, table, man, warm, modern, rings, similar, wearing, sweatpants, cozy, old, inviting, guy
# PqpCeiYycVM: books, girl, literally, obsessed, dad, art, new, insane, congrats
# Pt_5Faa_J-U: kind, მინეტი, spot, дом, cold, art, sorry, russia, tennis, maple, შენი, inviting, sara, tree, ზარბო, concrete, warm, hubby, მოვტყან, შარაპოვა, ვთხარე, walls
# QMCR45FyfzU: pants, energy, muay, tshirt, hand, brienne, shirt, jaime, back, fern, fookin, leo, thai, lion, simple, doll, มวยไทย, lannister, jamie, course, man, guy
# Qc0iJpQcdis: marin, dining, idea, even, hotel, pots, wallpaper, ceiling, kitchen, hanna, laundry
# QvoPw_5Sz8U: make, mouse, couple, channel, wallpaper, club, utah, fireplace, kitchen, perfect, attention, fender, spice
# RDn0K9UzCpc: decor, bronx, dog, girl, outfit, view, skirt, pope
# RF-Mqs2qC-M: skittles, made, kind, hell, alia, machine, idea, door, mansion, tree, ali, small, million, man, dude, came, hotel, perfect, pot, poor
# RNjlfo_8u4s: beets, tell, office, farms, mose, dwight, warm, beet, couple, use, schrute, mindy, shrute, lord, fun, guy, farm
# RjVfU9WcPxE: back, food, broke, ago, man, art, energy, guy, roman, chef, bloscar
# S1_L6RGDggk: sweater, beach, cardigan, dog, man, boys, dude, art, wife, tall, american, guy
# SVO-iq2bjTQ: decor, bed, spot, sofa, sunshine, elm, pictures, girl, table, lamp, first, small, light, definitely, sweet, chair, moment, surrounded
# SrlAlMsdr3g: supernatural, creepy, couple, winchester, bathroom, doll, wife, kids, toilet, clean, might, tree
# TPEdTajhR6A: thinking, conditioning, sam, air, waiting, hat, couple, dark, family, cozy, gen, different, supernatural, earth, humble
# UAUfo6KY1wg: clothes, blue, trust, couple, color, fashion, universe, mediterranean, outdoor, buy, white
# UYEWJcmWKGQ: power, simply, warm, couple, black, favourite, hang, husband, talk
# VTPdktgrtF8: office, studio, zhc, come, ronald, far, work, incredible, limes, mural
# VabOWgtG2D4: children, couple, art, kitchen, enjoy, kids, family
# VxvfhuxOE1I: barn, creepy, interesting, horses, around, church, chapel, property, ebay
# VyEf4EBXe8o: pod, baseball, child, lmao, views, dad, sucker, grandma, shoes, tesla, picture, old, million, year, juul, fish, bowl, kids, wait, led, mango, tie, snoop
# VylU-ueLA_g: soulless, papa, come, uncle, roger, art, austin, minimalist, nothing, kitchen, youtube, bro, guy
# X89WJTXA8KQ: colors, color, bedroom, energy, sweet, full
# XNrTIQjHuKs: hey, columbus, lip, cyrus, coolest, couple, ohio, gomez, miley, sounds, bust, corn, bite, hair, dwayne, jessie
# XxPPdlo72ho: chandelier, collection, creepy, collector, wall, doll, dolls, hate, bathroom, cozy, celebrity, ship
# YQC7OtyHhxU: human, blah, heart, mug, man, candle, husband, gay, note, close, vision, sweet, closet, lot, basement
# _Jqi9k3tXoQ: piano, name, world, keep, song, loft, expensive, bathroom, bidet, dimmer, new, city, bangs, york, plants
# _Zr3ObadDnI: big, trump, man, letter, couple, uncle, scott, wife, billy, full, family
# aB7JCNRI3rY: glass, beautifully, wall, idea, wallpaper, paper, kitchen, makes, cabinets, windows
# aTSgJgRnqG0: knew, goddess, coming, warm, sound, idea, gay, durga, times, mitch, expecting, mitchell, cam, idol
# eOfOrQJWeP0: big, rest, bad, chairs, office, kev, throw, oprah, katt, couch, bar, cursed, logo, guy
# eyUs2JgrV9E: piano, man, couple, iron, listing, art, virgo, music, listen, peace, dollar, museum, played, part, woman, play, playing, million
# fsYZye1Ykao: children, beach, marble, tequila, black, small, anatomy, grey, kitchen, meredith, greys
# gKUyX7cjum4: decor, knew, jai, chairs, umbrella, couple, stp, bedroom, wallpaper, future, mas, academy
# gO_gm74yiUY: freebritney, waiting, inspired, speak, reminds, universe, energy, said, ear, bret, deserves, plants, filipino, miss, piece, wearing, earrings, humble, catriona, turtles, gay, chair
# hJaXjItxL6w: mom, illuminati, first, send, man, make, skateboarding, worth, skate, must, wait, neck, guy, plants, million, usa
# haK2TnmVoT0: candles, vagina, cold, spa, maybe, kitchen, bedrooms, smell
# iY1UnR7z7P0: doping, built, dope, bought, man, keep, pay, art, cancer, cheating, cheat, pays, shame, comments, guy
# jOzaz27K48E: pants, dope, rugs, man, cozy, halsey, bay, green, kitchen, eazy, zimbabwe, gerald, crib, essential, high, guy
# jY3P-f6q-ZI: pink, dining, color, wallpaper, husband, makes
# jwfI8BlFwMw: yet, architectural, digest, notice, couple, bottle, wes, wife, car, backwards, marriage, big, driving, window, family, wine, toys, age, squidward, hope
# kavjzsRtuuA: fun, kind, guy, couch
# l2mtebeR3rA: mom, shower, mexican, pinterest, wall, age, husband, around, fence, kid, kids, family, santa, pool, white
# n50DZvVAulM: sofas, waiting, curious, couple, bedroom, dining, pieces, art, homey, painting, paintings, rent, completely, cozy, saving, kids, blur
# ou3h0twV9TY: mask, tell, lamp, etsy, phone, ghost, painting, story, behind, laughed, face, queenie, door, hard, guy
# pJ8hLOkhl7M: moment, couple, wes, anderson, miami, vampire, old, pink, man, age, hotel, library, gay, instagrammable, awkward, ken, sales, welcome, looking
# qNthtD7KmiA: bad, reference, dog, brick, door, relatable, open, art, carrying, limes, regretsy, woman, fun
# qmHAvgEBnsk: eggs, man, dad, lotus, interior, wife, cluttered, american, dante, guy, white
# rHyIOIstYRA: stuffed, animals, interesting, bedroom, cat, dead, kitchen, dust, mean, dita, woman, white
# sQTGkLW6fwg: cheryl, set, netflix, fake, blossom, season
# uXYyyhUcFg4: dog, enzo, natural, man, japanese, drinking, water, far, sneakers, temple, pool, hair, dogs, humble, guy
# uZDNGVmHxn4: vestibule, rules, dope, man, dude, interior, wife, kitchen, new, family
# ua0-5FZ2Eww: kind, make, kitchen, new, makes, youtube, jesus, guy
# v293iGJ2PVY: feels, jake, couple, sweet, family, kids, fake, tree
# vDD1lhHkGxk: new, closet, buddha, nyc, statue, couple, shot, husband, parker, buddhist, closets, family, mitch, award, cam, tony, man, gay, york
# vGqYP1sKJ2Y: kim, products, laughs, man, lighter, dude, work, houseplant, rogen, smoke, guy
# vvrjhuJrFVc: arthur, favourite, history, incredible, rackham, london, kept, garden, next, old
# vx09_4cEzlM: vagina, coolest, tunnel, tiger, ball, even, crazy, fun, unique
# w4HmK4JCN2U: cottage, magical, holiday, gabby, perfect, cozy
# xT8n0uBIURk: restaurant, fak, food, bathroom, bear, wait, congrats, looking
# xqv0yo_Elj4: furniture, dog, sustainable, master, bella, accent, bedroom, light, vintage, bla, walls
# yKn3Ur6_w3c: cleaning, books, chuys, chuy, let, rip, literally, feet, bravo, sauna, whole, smoke, ice, everywhere
# yjhibJ-OqxE: girl, kardashian, said, used, glad, art, sign, hear, whole, family, cozy, sisters, poor
# zEXXe9Ef_R8: bed, bedwomb, man, couple, charming, lilly, bedroom, bathroom, floor, refugees, swan, entire, carpet, closet
# zPUSDU0hrwE: colors, cottage, chastain, color, charming, fan, low, new, cozy, woman
# za-ogD7nLi8: gift, make, black, husband, art, balls, bowl, makes, sunglasses, philippines, bowls
# zgacuXdzCmw: trump, incredible, congrats, hollywood, inside, sided, built, studio, inspiring, respect, mansion, genius, bar, congratulations, man, black, dude, wait, sold, guy, white
#
# Most common words:
# house: 324
# love: 306
# like: 269
# home: 195
# beautiful: 173
# one: 105
# would: 85
# nice: 82
# looks: 80
# much: 76
# wow: 64
# gorgeous: 63
# amazing: 59
# see: 57
# know: 53
# room: 50
# lol: 47
# cool: 42
# people: 40
# want: 39
# guy: 37
# lovely: 36
# style: 35
# couple: 35
# best: 34
# art: 30
# seen: 30
# place: 28
# man: 28
# ever: 28
# video: 27
# family: 27
# cozy: 26
# taste: 25
# cute: 24
# kitchen: 24
# good: 24
# omg: 23
# everything: 22
# stunning: 22
# well: 21
# absolutely: 20
# get: 20
# space: 20
# look: 20
# loved: 18
# anyone: 18
# tour: 17
# kids: 17
# apartment: 17
# money: 16
# design: 15
# vibe: 14
# could: 14
# seems: 14
# way: 13
# favorite: 13
# girl: 13
# happy: 13
# wife: 13
# bathroom: 12
# office: 12
# woman: 11
# white: 11
# rich: 11
# thank: 11
# two: 11
# still: 11
# need: 11
# every: 11
# dog: 11
# feel: 10
# show: 10
# many: 9
# black: 9
# got: 9
# damn: 9
# bedroom: 9
# time: 9
# gay: 9
# please: 9
# hotel: 9
# husband: 9
# sweet: 8
# thought: 8
# blurred: 8
# homes: 8
# new: 8
# fun: 8
# dude: 8
# voice: 7
# tree: 7
# someone: 7
# yes: 7
# actually: 7
# done: 7
# god: 7
# life: 7
# going: 7
# energy: 7
# wallpaper: 7
# ariel: 7
# pretty: 6
# laugh: 6
# closet: 6
# color: 6
# person: 6
# together: 6
# garden: 6
# though: 6
# always: 6
# warm: 6
# thing: 6
# interior: 6
# door: 5
# unique: 5
# cold: 5
# old: 5
# vibes: 5
# also: 5
# day: 5
# else: 5
# episode: 5
# say: 5
# que: 5
# think: 5
# decor: 5
# melo: 5
# little: 5
# age: 5
# loves: 5
# awesome: 5
# books: 5
# big: 5
# never: 5
# rooms: 5
# proud: 5
# riverdale: 5
# queen: 4
# job: 4
# watch: 4
# sharing: 4
# thanks: 4
# castle: 4
# married: 4
# lady: 4
# creepy: 4
# right: 4
# baby: 4
# furniture: 4
